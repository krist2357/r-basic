# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.tau
# Out:
# 6.283185307179586

# %%
math.inf
# Out:
# inf

# %%
-math.inf
# Out:
# -inf

# %%
float('inf')
# Out:
# inf

# %%
math.nan
# Out:
# nan

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-11-9e1622b385b6> in <module>
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
sqrt(-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-dc0ac523cb01> in <module>
# ----> 1 sqrt(-1)
#
# NameError: name 'sqrt' is not defined

# %%
math.sqrt(-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-2037b8d41d70> in <module>
# ----> 1 math.sqrt(-1)
#
# ValueError: math domain error

# %%
math.pow(math.nan, 0)
# Out:
# 1.0

# %%
math.nan+5
# Out:
# nan

# %%
math.e(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-d87db609d5cf> in <module>
# ----> 1 math.e(1)
#
# TypeError: 'float' object is not callable

# %%
math.exp(1)
# Out:
# 2.718281828459045

# %%
math.exp(1000)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-19-e0c11add5017> in <module>
# ----> 1 math.exp(1000)
#
# OverflowError: math range error

# %%
1+1
# Out:
# 2

# %%
3/5
# Out:
# 0.6

# %%
2*6
# Out:
# 12

# %%
-2
# Out:
# -2

# %%
math.ceil(3.4523)
# Out:
# 4

# %%
math.floor(3.4523)
# Out:
# 3

# %% [markdown]
# $\int_0^1 x^2 dx$

# %%
math.copysign(3, -2)
# Out:
# -3.0

# %%
math.copysign(3, -0.0)
# Out:
# -3.0

# %%
math.fabs(5)
# Out:
# 5.0

# %%
math.fabs(-5.0)
# Out:
# 5.0

# %%
math.trunc(3.4568)
# Out:
# 3

# %%
2**5
# Out:
# 32

# %%
math.factorial(4)
# Out:
# 24

# %%
math.fmod(7,3)
# Out:
# 1.0

# %%
7%3
# Out:
# 1

# %%
7/3
# Out:
# 2.3333333333333335

# %%
7//3
# Out:
# 2

# %%
math.remainder(7,3)
# Out:
# 1.0

# %%
math.modf(4.25)
# Out:
# (0.25, 4.0)

# %%
math.gcd(24, 36)
# Out:
# 12

# %%
math.isclose(math.sqrt(2)**2,2)
# Out:
# True

# %%
math.sqrt(2)**2==2
# Out:
# False

# %% [markdown]
# # FUNCIONES MATEMATICAS

# %%
math.exp(3)
# Out:
# 20.085536923187668

# %%
math.e**3
# Out:
# 20.085536923187664

# %%
math.pow(math.e, 3)
# Out:
# 20.085536923187664

# %%
math.expm1(1)
# Out:
# 1.718281828459045

# %%
math.exp(1)-1
# Out:
# 1.718281828459045

# %%
math.exp(1e-05)-1
# Out:
# 1.0000050000069649e-05

# %%
math.expm1(1e-05)
# Out:
# 1.0000050000166667e-05

# %%
math.log(12)
# Out:
# 2.4849066497880004

# %%
math.log(12, 2)
# Out:
# 3.5849625007211565

# %%
math.log1p(1e-5)
# Out:
# 9.99995000033333e-06

# %%
math.log2(32)
# Out:
# 5.0

# %%
math.log10(100000)
# Out:
# 5.0

# %%
math.sin(2*math.pi)
# Out:
# -2.4492935982947064e-16
