# %%
import math

# %% [markdown]
# # PROBLEMA1

# %%
numeroReal = float(input("Ingrese el valor de un numero real:"))
# Out:
# Ingrese el valor de un numero real:-2.55

# %%
if(numeroReal>0):
    print("Es un numero positivo")
elif(numeroReal<0):
    print("Es un numero negativo")
# Out:
# Es un numero negativo

# %% [markdown]
# # PROBLEMA2

# %%
numeroReal = float(input("Ingrese el valor de un numero real:"))
# Out:
# Ingrese el valor de un numero real:-5.84

# %%
if(numeroReal > -5 and numeroReal < 5):
    print("El numero Real esta dentro el rango entre -5 y 5")
else:
    print("El número Real está fuera del rango entre -5 y 5")
# Out:
# El número Real está fuera del rango entre -5 y 5

# %% [markdown]
# # PROBLEMA 3

# %%
x = float(input("Ingrese el eje de las abscisas:"))
# Out:
# Ingrese el eje de las abscisas:-1

# %%
y = float(input("Ingrese el eje de las ordenadas:"))
# Out:
# Ingrese el eje de las ordenadas:-3

# %%
if(x > 0 and y > 0):
    print("La coordenada esta en el primer cuadrante")
elif(x < 0 and y > 0):
    print("La coordenada esta en el segundo cuadrante")
elif(x < 0 and y < 0):
    print("La coordenada esta en el tercer cuadrante")
elif(x > 0 and y < 0):
    print("La coordenada esta en el cuarto cuadrante")
# Out:
# La coordenada esta en el tercer cuadrante

# %% [markdown]
# # PROBLEMA 4

# %%
x = int(input("Ingrese el numero entero dividendo:"))
# Out:
# Ingrese el numero entero dividendo:19

# %%
y = int(input("Ingrese el numero entero divisor:"))
# Out:
# Ingrese el numero entero divisor:8

# %%
print("El residuo es:"+str(math.fmod(x,y)))
# Out:
# El residuo es:3.0

# %%
print("El cociente es:"+str(x//y))
# Out:
# El cociente es:2

# %% [markdown]
# # PROBLEMA 5

# %%
x = int(input("Ingrese el numero real mayor que cero:"))
# Out:
# Ingrese el numero real mayor que cero:16

# %%
y = math.sqrt(x)

# %%
[v, w] = math.modf(y)

# %%
if(v == 0.0):
    print("El número es un cuadrado perfecto")
elif(v > 0.0):
    print("El número no es cuadrado perfecto")
# Out:
# El número es un cuadrado perfecto

# %% [markdown]
# # PROBLEMA 6

# %%
x = int(input("Ingrese número mayor que cero:"))
# Out:
# Ingrese número mayor que cero:2020

# %%
b = x/4

# %%
y = x/100

# %%
[c, d] = math.modf(b)

# %%
[v, w] = math.modf(y)

# %%
[z, a] = math.modf(x/400)

# %%
if(c == 0 and v == 0 and z == 0):
    print("Es año Bisiesto")
elif(c == 0 and v == 0 and z > 0):
    print("No es año Bisiesto")
elif(c == 0 and v > 0 and z == 0):
    print("Es año bisiesto")
elif(c == 0 and v > 0 and z > 0):
    print("Es año bisiesto")
elif(c > 0 and v == 0 and z == 0):
    print("No es año bisiesto")
elif(c > 0 and v == 0 and z > 0):
    print("No es año bisiesto")
elif(c > 0 and v > 0 and z == 0):
    print("No es año bisiesto")
elif(c > 0 and v > 0 and z > 0):
    print("No es año bisiesto")
# Out:
# Es año bisiesto

# %% [markdown]
# # PROBLEMA 7

# %%
filas = ["a", "c", "e", "g"]

# %%
columnas = [1, 2, 3, 4, 5, 6, 7, 8]

# %%
x = str(input("ingrese el valor de la fila:"))
# Out:
# ingrese el valor de la fila:c

# %%
y = int(input("Ingrese el valor de la columna:"))
# Out:
# Ingrese el valor de la columna:1

# %%
filter_columna = list(filter(lambda m: (math.fmod(m,2)!=0), columnas))

# %%
filter_columna
# Out:
# [1, 3, 5, 7]

# %%
if (x == "c"):
    print()
else
# Out:
#   File "<ipython-input-164-4d293c6e5d93>", line 3
#     else
#         ^
# SyntaxError: invalid syntax
