# %%
print("Hola Universe")
# Out:
# Hola Universe

# %%
x=7
print(x)
# Out:
# 7

# %%
print("El valor de la variable x:"+str(x))
# Out:
# El valor de la variable x:7

# %%
texto=input("Ingrese el nombre del 8 planeta:")
# Out:
# Ingrese el nombre del 8 planeta:neptuno

# %%
texto
# Out:
# 'neptuno'

# %%
numero=int(input("introduce tu edad"))
# Out:
# introduce tu edad38

# %%
numero
# Out:
# 38

# %%
x=int(input("Escribe un número:"))
# Out:
# Escribe un número:5

# %%
if x ==5:
    print("Has escrito el número 5")
# Out:
# Has escrito el número 5

# %%
x=int(input("Escribe un número:"))
if x < 5:
    print("Has escrito un numero menor que 5")
elif x < 10:
    print("Has escrito un numero menor que 10 y mayor que 5")
else:
    print("El numero que has escrito es mayor o igual que 10")
# Out:
# Escribe un número:6
# Has escrito un numero menor que 10 y mayor que 5

# %%
x=int(input("Escribe un número:"))
if x > 0 and x < 10:
    print("Has escrito un numero en el rango entre 0 y 10")
# Out:
# Escribe un número:11

# %%
#FUNCIONES MATEMATICAS
