# %%
import numpy as np
import operator # Libreria para trabajar con el metodo sorted.
L1=["JUAN","ARAGON","CHRISTIAN","MAXIMO"]
x=np.arange(4)
cuenta1=0
for i in L1: # guardo los nombres en la variable i
    print("El nombre de la lista es:%s"%i)
    
    a=list(i)# Para poder usar objetos, hay que convertir el strig en lista
    a.sort() #Metodo que ordena caracteres
    st="" #Defino un string vacio
    b=st.join(a) #Metodo que transforma a string una lista
    print("El nombre ordenado por letras es:%s"%b)
    
    a.reverse() #Metodo reversa
    st=""
    b=st.join(a)
    print("El nombre alfabeticamente en reversa es:%s"%b)
    
    cuenta1=cuenta1+1 #Contar el numero de elemntos de la lista L1
    
    cuenta2 = 0
    for k in i: 
        cuenta2=cuenta2+1 #contar los caractares de cada nombre de la lista L1
    
    x[cuenta1-1]=cuenta2 #Asigno al vector x el nuemro de caracteres de cada nombre



D1=dict(zip(L1,x))
print("El diccionario original es:")
print(D1.keys())

D2=sorted(D1.items(),key=operator.itemgetter(1))
D3=np.ravel(D2)
print("El diccionario ordenado por cantidad de caractaeres es:")
print(D2)
# Out:
# El nombre de la lista es:JUAN
# El nombre ordenado por letras es:AJNU
# El nombre alfabeticamente en reversa es:UNJA
# El nombre de la lista es:ARAGON
# El nombre ordenado por letras es:AAGNOR
# El nombre alfabeticamente en reversa es:RONGAA
# El nombre de la lista es:CHRISTIAN
# El nombre ordenado por letras es:ACHIINRST
# El nombre alfabeticamente en reversa es:TSRNIIHCA
# El nombre de la lista es:MAXIMO
# El nombre ordenado por letras es:AIMMOX
# El nombre alfabeticamente en reversa es:XOMMIA
# El diccionario original es:
# dict_keys(['JUAN', 'ARAGON', 'CHRISTIAN', 'MAXIMO'])
# El diccionario ordenado por cantidad de caractaeres es:
# [('JUAN', 4), ('ARAGON', 6), ('MAXIMO', 6), ('CHRISTIAN', 9)]
